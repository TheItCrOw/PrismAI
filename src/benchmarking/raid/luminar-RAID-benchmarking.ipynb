# %% [markdown]
# # Luminar

# %% [markdown]
# ## Minimal Code

# %%
import os.path

import torch

from typing import Iterable, NamedTuple
from pathlib import Path
from datasets import Dataset
from torch import nn
from torch.utils.data import DataLoader, Subset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    PreTrainedModel,
    PreTrainedTokenizer,
)

# %% [markdown]
# ### Luminar Encoder
#
# 1. Pre-Process Inputs: tokenize and pass through LLM, recording hidden states
# 2. Calculate _Intermediate Likelihoods_: pass each hidden state through the models LM head

# %%
class LuminarEncoder:
    def __init__(
        self,
        feature_dim: int = 256,
        model_name_or_path: str = "gpt2",
        device: str = ("cuda:0" if torch.cuda.is_available() else "cpu"),
    ):
        self.feature_dim = feature_dim
        self.device = torch.device(device)

        self.tokenizer: PreTrainedTokenizer = AutoTokenizer.from_pretrained(
            model_name_or_path
        )
        if not hasattr(self.tokenizer, "pad_token") or self.tokenizer.pad_token is None:
            self.tokenizer.pad_token = self.tokenizer.eos_token
        self.pad_token_id = self.tokenizer.pad_token_id

        self.model: PreTrainedModel = AutoModelForCausalLM.from_pretrained(
            model_name_or_path
        )
        self.model = self.model.to(self.device)

        if hasattr(self.model, "lm_head"):
            self.model_lm_head: nn.Linear = self.model.lm_head
        elif hasattr(self.model.model, "lm_head"):
            self.model_lm_head: nn.Linear = self.model.model.lm_head
        else:
            raise ValueError("Could not find lm_head in model")

    def __call__(self, batch: dict[str, list[str]]) -> dict[str, list[torch.Tensor]]:
        return {"features": self.process(batch["text"])}

    def process(self, batch: list[str]) -> list[torch.Tensor]:
        encoding = self.tokenizer(
            batch,
            padding=True,
            truncation=True,
            max_length=self.feature_dim,
            return_tensors="pt",
        )
        batch_hidden_states = self.forward(encoding.input_ids, encoding.attention_mask)

        intermediate_likelihoods = []
        for input_ids, hidden_states in zip(encoding.input_ids, batch_hidden_states):
            intermediate_likelihoods.append(
                self.compute_intermediate_likelihoods(input_ids, hidden_states)
            )

        return intermediate_likelihoods

    @torch.no_grad()
    def forward(
        self,
        input_ids: torch.Tensor,
        attention_mask: torch.Tensor,
    ) -> Iterable[tuple[torch.Tensor, ...]]:
        outputs = self.model(
            input_ids=input_ids.to(self.device),
            attention_mask=attention_mask.to(self.device),
            output_hidden_states=True,
        )

        # unpack hidden states to get one list of tensors per input sequence,
        # instead of one hidden state per layer in the model
        return zip(*outputs.hidden_states)  # type: ignore

    @torch.no_grad()
    def compute_intermediate_likelihoods(
        self,
        input_ids: torch.Tensor,
        hidden_states: tuple[torch.Tensor],
    ) -> torch.Tensor:
        labels = input_ids[1:].view(-1, 1)

        seq_length = min(labels.ne(self.pad_token_id).sum(), self.feature_dim)
        labels = labels[:seq_length].to(self.device)

        intermediate_likelihoods = []
        for hs in hidden_states:
            hs: torch.Tensor = hs[:seq_length].to(self.device)
            il = (
                # get layer logits
                self.model_lm_head(hs)
                # calculate likelihoods
                .softmax(-1)
                # get likelihoods of input tokens
                .gather(-1, labels)
                .squeeze(-1)
                .cpu()
            )
            del hs

            # pad with zeros if sequence is shorter than required feature_dim
            if seq_length < self.feature_dim:
                il = torch.cat([il, torch.zeros(self.feature_dim - seq_length)])

            intermediate_likelihoods.append(il)

        # stack intermediate likelihoods to get tensor of shape (feature_dim, num_layers)
        return torch.stack(intermediate_likelihoods, dim=1)

# %% [markdown]
# ### Luminar Classifier
#
# CNN-based classifier using _Intermediate Likelihoods_ as input features.
# Here, we utilize these inherently 2D values (`seq_len * num_layers`) as 1D inputs where the second dimension is treated as input channels.

# %%
class ConvolutionalLayerSpec(NamedTuple):
    channels: int
    kernel_size: int | tuple[int, int]
    stride: int = 1

    @property
    def kernel_size_1d(self):
        if isinstance(self.kernel_size, int):
            return self.kernel_size
        return self.kernel_size[0]

    @property
    def kernel_size_2d(self):
        if isinstance(self.kernel_size, int):
            return (self.kernel_size, self.kernel_size)
        return self.kernel_size

    @property
    def padding(self) -> int:
        return (self.kernel_size_1d - 1) // 2

    def __repr__(self):
        return repr(tuple(self))


DEFAULT_CONV_LAYER_SHAPES = ((64, 5), (128, 3), (128, 3), (128, 3), (64, 3))


class LuminarClassifier(nn.Module):
    def __init__(
        self,
        conv_layer_shapes: Iterable[ConvolutionalLayerSpec] = DEFAULT_CONV_LAYER_SHAPES,
        projection_dim: int | None = None,
    ):
        super().__init__()
        self.conv_layers = nn.Sequential()
        for conv in conv_layer_shapes:
            conv = ConvolutionalLayerSpec(*conv)
            self.conv_layers.append(
                nn.LazyConv1d(
                    conv.channels,
                    conv.kernel_size,  # type: ignore
                    conv.stride,
                    conv.padding,
                ),
            )
            self.conv_layers.append(
                nn.LeakyReLU(),
            )
        self.conv_layers.append(nn.Flatten())

        if projection_dim:
            self.projection = nn.Sequential(
                nn.LazyLinear(projection_dim), nn.LeakyReLU()
            )
        else:
            self.projection = nn.Identity()

        self.classifier = nn.LazyLinear(1)

    def forward(self, features: torch.Tensor):
        # We are using 2D features (so `features` is a 3D tensor)
        # but we want to treat the second feature dimension as channels.
        # Thus, we need to transpose the tensor here
        features = features.transpose(1, 2)

        for layer in self.conv_layers:
            features = layer(features)

        return self.classifier(self.projection(features.flatten(1)))

# %% [markdown]
# ### Encode Samples

# %%
encoder = LuminarEncoder(128, model_name_or_path="gpt2")

# %%
notebook_dir = Path.cwd()
project_root = notebook_dir.parent.parent

MODEL_VERSION = 'luminar_classifier_RAID.pt'
MODEL_PATH = project_root / 'luminar' / 'models' / MODEL_VERSION
print(MODEL_PATH)
# Out:
# /home/staff_homes/kboenisc/home/prismAI/PrismAI/src/luminar/models/luminar_classifier_RAID.pt

# %%
model = LuminarClassifier()
model.load_state_dict(torch.load(MODEL_PATH))
model = model.to(encoder.device)
model.eval()
# Out:
# LuminarClassifier(
#   (conv_layers): Sequential(
#     (0): LazyConv1d(0, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): LazyConv1d(0, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): LazyConv1d(0, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): LazyConv1d(0, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#     (7): LeakyReLU(negative_slope=0.01)
#     (8): LazyConv1d(0, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (9): LeakyReLU(negative_slope=0.01)
#     (10): Flatten(start_dim=1, end_dim=-1)
#   )
#   (projection): Identity()
#   (classifier): LazyLinear(in_features=0, out_features=1, bias=True)
# )

# %%
from raid import run_detection, run_evaluation
from raid.utils import load_data

# %%
from tqdm import tqdm

ROUND_PREDICTIONS = True

def my_detector(texts: list[str], batch_size: int = 128) -> list[float]:
    y_pred = []

    for i in tqdm(range(0, len(texts), batch_size), desc="Detecting"):
        batch_texts = texts[i:i+batch_size]

        with torch.no_grad():
            encoded = encoder({"text": batch_texts})
            features: list[torch.Tensor] = encoded["features"]
            features_batch = torch.stack(features).to(encoder.device)

            logits = model(features_batch)
            if ROUND_PREDICTIONS:
                pred = logits.sigmoid().round().squeeze(-1)
            else:
                pred = logits.sigmoid().squeeze(-1)

            y_pred.extend(pred.tolist())

    return y_pred

# %%
# Load RAID test
INCLUDE_ADVERSARIAL = True

test_df = load_data(split="test", include_adversarial=INCLUDE_ADVERSARIAL)#, include_adversarial=False)
test_df
# Out:
#                                           id  \
# 0       64005577-3d63-4583-8945-7541d3e53e7d
# 1       c2b9df67-4e29-45ca-bdcc-7065fb907b77
# 2       07904f22-8530-4d3b-bf49-6bd1642d89f7
# 3       dc5aa023-6f57-4f9c-833a-c0f322a994fa
# 4       1b1ab19b-fe6f-458d-a666-06bbc1791534
# ...                                      ...
# 671995  b2694dd7-1c4d-4bef-8e52-0c1e13d54130
# 671996  9e5c1a37-9305-4ca7-8dc0-ab1ed763231e
# 671997  a233aa5d-b375-423f-ad7a-ffc5045398c5
# 671998  e267ebb4-b1f7-4af4-b68b-ecd4ba565f93
# 671999  45df9738-b31c-495b-9a0d-2c62220df990
#
#                                                generation
# 0         The Sunspot Number, created by R.Wolf in 184...
# 1         We present several analogies between convex ...
# 2         Let H be a homology theory for algebraic var...
# 3         The two parallel concepts of "small" sets of...
# 4         We present new solutions to the strong explo...
# ...                                                   ...
# 671995  R​o​n​n​i​e​ ​N​u​n​n​ ​i​s​ ​a​n​ ​A​m​e​r​i​...
# 671996  L​e​s​t​e​r​ ​M​.​ ​W​o​l​f​s​o​n​ ​w​a​s​ ​a​...
# 671997  L​e​s​t​e​r​ ​M​.​ ​W​o​l​f​s​o​n​ ​w​a​s​ ​a​...
# 671998  J​u​s​t​i​n​i​a​n​ ​R​w​e​y​e​m​a​m​u​ ​(​b​o​...
# 671999  J​u​s​t​i​n​i​a​n​ ​R​w​e​y​e​m​a​m​u​ ​(​b​o​...
#
# [672000 rows x 2 columns]

# %%
predictions = run_detection(my_detector, test_df)
predictions
# Out:
# Detecting: 100%|█████████████████████████████████████████████████████████████████████████████████████████| 5250/5250 [1:40:01<00:00,  1.14s/it]
# [{'id': '64005577-3d63-4583-8945-7541d3e53e7d', 'score': 1.0},
#  {'id': 'c2b9df67-4e29-45ca-bdcc-7065fb907b77', 'score': 1.0},
#  {'id': '07904f22-8530-4d3b-bf49-6bd1642d89f7', 'score': 1.0},
#  {'id': 'dc5aa023-6f57-4f9c-833a-c0f322a994fa', 'score': 1.0},
#  {'id': '1b1ab19b-fe6f-458d-a666-06bbc1791534', 'score': 1.0},
#  {'id': 'a5dd2abc-eac8-485a-ab60-ee5fa52e745d', 'score': 1.0},
#  {'id': '2842f045-a940-49ad-aee8-4d07d7bf8cef', 'score': 1.0},
#  {'id': 'd02030b5-5f2b-4984-a258-4f5f82adeb69', 'score': 1.0},
#  {'id': 'f9119497-bdfc-47b3-9da3-454f3342eccc', 'score': 1.0},
#  {'id': '963a9c65-ed4b-441f-bfaf-9b06ccd9abec', 'score': 1.0},
#  {'id': '869d5f44-5b5d-4bcf-bc43-400780d815c6', 'score': 1.0},
#  {'id': '4d1fea55-dee8-4d1c-bbeb-7633d76209ad', 'score': 1.0},
#  {'id': '95ffaeda-006e-4b03-95ab-e61f42bd822c', 'score': 1.0},
#  {'id': '1b2ac125-0040-4485-b32a-0b43625e0396', 'score': 1.0},
#  {'id': 'e1c0bfa2-97ca-4183-b2f4-dd5ea9046f2e', 'score': 1.0},
#  {'id': '4c59ab6b-72c3-47a6-a5d0-0246085541e2', 'score': 1.0},
#  {'id': 'd800bd16-c2f8-43b3-8806-4a60f39c0b9d', 'score': 1.0},
#  {'id': 'a0c8d204-32ce-408d-9d02-675b7e64528e', 'score': 1.0},
#  {'id': 'be14065a-6f91-4db3-8c80-5f611841d215', 'score': 1.0},
#  {'id': 'f82dd650-b3f8-4814-bf89-203324fb9670', 'score': 1.0},
#  {'id': 'a4df3371-0115-46f0-858a-035e1a0a91c2', 'score': 1.0},
#  {'id': 'b95d387b-bba8-46c4-b5d4-555eba0365c8', 'score': 1.0},
#  {'id': '3381c0b1-d102-4305-a328-eec4678046f8', 'score': 1.0},
#  {'id': '7ab9467e-d363-4086-a1ca-59a9db3b0b79', 'score': 1.0},
#  {'id': 'a7ae18cc-9fb2-4c61-8af7-b8b1de4dc7ab', 'score': 1.0},
#  {'id': '5c61529c-1094-40f8-bfcd-d0ca3c324082', 'score': 1.0},
#  {'id': 'a0f8be92-f8ef-461c-9a3d-10b352fafb70', 'score': 1.0},
#  {'id': '8099d65b-bcc1-4f12-b1a9-07b60890cf1c', 'score': 1.0},
#  {'id': '56afadc8-cf67-4516-bc91-876bd69ef940', 'score': 1.0},
#  {'id': '15e3c7ab-2c37-4932-bf2b-c0c1cfe415a1', 'score': 1.0},
#  {'id': '276217f8-c981-4e4e-914b-bd9d4d2f07fd', 'score': 1.0},
#  {'id': '4c5acb89-ad8c-4577-b816-c9b34a78dfc2', 'score': 1.0},
#  {'id': 'b71bde0e-11fa-4057-adbc-90d21a133df7', 'score': 1.0},
#  {'id': 'a1f7bac9-fa1c-49e5-9dfa-fdfd7e02fdef', 'score': 1.0},
#  {'id': '43759080-3a40-47b0-8f14-0644a5f4179c', 'score': 1.0},
#  {'id': 'e9d37b29-8212-498f-8856-3caf15b5b034', 'score': 1.0},
#  {'id': '0f173dc3-3847-431c-b90d-d0048c21e04c', 'score': 1.0},
#  {'id': 'db71d85f-76e3-479e-ab34-0f4c032183e6', 'score': 1.0},
#  {'id': '9caabc69-ed9f-4e80-9313-e239defd4ac0', 'score': 1.0},
#  {'id': 'db80aae4-893c-478a-bf20-8ac148ec0dea', 'score': 1.0},
#  {'id': 'f0a0db19-f781-4123-8d93-573db6a87514', 'score': 1.0},
#  {'id': 'c30d8ba3-5ac7-47bd-b374-c73499b100dc', 'score': 1.0},
#  {'id': '7b5c8aa1-b870-4d89-b7dd-9f215ad2c415', 'score': 1.0},
#  {'id': 'd1762d17-2013-43f8-9f13-5381c039a910', 'score': 1.0},
#  {'id': '89999048-281a-4693-9be6-36ee1c01050d', 'score': 1.0},
#  {'id': '42685ef3-30de-40c2-8130-d6db5054df09', 'score': 1.0},
#  {'id': '88af9468-5fc2-4302-a05a-70e91ba67ebe', 'score': 1.0},
#  {'id': '0a21d9a1-b0c6-4da8-bf27-cc250d25ea0b', 'score': 1.0},
#  {'id': '7827b8b1-5418-4888-a328-3f9b585be62a', 'score': 1.0},
#  {'id': '73708039-95ab-425d-aa97-9d0eb42c1b46', 'score': 1.0},
#  {'id': '6242bee7-78c7-4db0-b55c-db9c60043906', 'score': 1.0},
#  {'id': '60b4294b-dbba-4a0e-9201-4731801ce332', 'score': 1.0},
#  {'id': 'cd0e0340-653d-466d-b79c-aa3a03f272b8', 'score': 1.0},
#  {'id': '9e2228de-daef-4863-b504-2d293659c1d0', 'score': 1.0},
#  {'id': '0f445eef-77b9-42d3-b0ef-0c8dc6085da7', 'score': 1.0},
#  {'id': 'd583be73-313d-4df9-80a0-aa1251b1a00d', 'score': 1.0},
#  {'id': 'be8659b4-5773-4d28-8c57-7761c88df403', 'score': 1.0},
#  {'id': '0ecb8e91-4ff5-4fe4-8249-350aaeeb6e4b', 'score': 1.0},
#  {'id': 'd4628d52-4323-45c9-9706-6a81dfad19d0', 'score': 1.0},
#  {'id': 'b0ccbef9-d2b5-4510-880c-1b703f62db00', 'score': 1.0},
#  {'id': 'bfa39241-baf7-491a-81f6-495796f34f7d', 'score': 1.0},
#  {'id': '775957bb-ab0e-4413-8f38-16762f7474a0', 'score': 1.0},
#  {'id': '94bc5b2b-e780-4a69-8613-7eb0b6527709', 'score': 1.0},
#  {'id': 'e3578adb-f027-46a5-8a5c-e15b0a0666fe', 'score': 1.0},
#  {'id': 'c5a5be0e-9e5c-4842-88a9-6643f7b2d91f', 'score': 1.0},
#  {'id': '69771f12-9ca0-40d9-90eb-699f7920e828', 'score': 1.0},
#  {'id': 'c73a021d-2a7e-4a5f-a732-48f4de0a3b4e', 'score': 1.0},
#  {'id': '1d8a8371-8b90-48f2-be28-03a55a855198', 'score': 1.0},
#  {'id': '9d54006a-14fc-4d67-9036-3d01c5f45caa', 'score': 1.0},
#  {'id': '82ced1ea-0895-4294-8bee-a5f9a4ccacd5', 'score': 1.0},
#  {'id': '8ef12e5b-c6e6-4b19-84fc-105151a4fbaa', 'score': 1.0},
#  {'id': 'df060fc4-0214-4442-8cdf-bcf0eabc8869', 'score': 1.0},
#  {'id': 'e49ea765-46c9-49dc-852d-a7ccb82a1def', 'score': 1.0},
#  {'id': '748195a5-27a2-4b16-bb83-6361e181ad5a', 'score': 1.0},
#  {'id': 'bb94c83d-2986-4e5a-9a8f-8d8ecaaec05b', 'score': 1.0},
#  {'id': '2d4dcce9-1ab0-4d88-80e6-7648fc5dd50d', 'score': 1.0},
#  {'id': 'ff60f969-e737-4a4e-8feb-a53e010188ff', 'score': 1.0},
#  {'id': 'f23efa21-992f-49b5-869f-8757ea1331b7', 'score': 1.0},
#  {'id': '623cc5b9-bca6-46d1-a71c-50cb2950f03a', 'score': 1.0},
#  {'id': 'c9b6436b-8942-46a2-b498-03bbb3d47044', 'score': 1.0},
#  {'id': 'bfe2abac-6e69-4126-906a-44f2d7e97209', 'score': 1.0},
#  {'id': '00d7c060-81dc-4921-9cf3-3485eaddc0fc', 'score': 1.0},
#  {'id': '9d238cae-7bba-4015-8f9f-27f67575f5c9', 'score': 1.0},
#  {'id': 'fc67fc8f-2417-4595-af3d-dde5c428a5e7', 'score': 1.0},
#  {'id': 'f393a625-97c6-4148-99e2-c968a04258f9', 'score': 1.0},
#  {'id': '939eb7ca-e2bb-4b0c-9fbc-27d28d0e9efc', 'score': 1.0},
#  {'id': 'abaf34c2-3070-4289-a055-b114fd763c41', 'score': 1.0},
#  {'id': 'cbe177c5-e4db-4eec-be10-5bf81fbc71be', 'score': 1.0},
#  {'id': '8184c9dc-b968-42f8-a32a-3527aff1a94c', 'score': 1.0},
#  {'id': '0724b3ac-a63d-4678-9cbc-84171142d8ee', 'score': 1.0},
#  {'id': 'f815f0cb-7b3c-49d1-83b6-b233563b809e', 'score': 1.0},
#  {'id': '9582c18b-58a1-4baa-9e54-ab43da07a011', 'score': 1.0},
#  {'id': 'a8dd3bd3-e680-4bd2-bcec-98aad90f8ded', 'score': 1.0},
#  {'id': '7badd607-3109-4502-aeff-39cf4acdc366', 'score': 1.0},
#  {'id': '399aa527-9d29-4b09-8edf-a388675c6f6c', 'score': 1.0},
#  {'id': '4634b33e-e6d2-4147-afc8-d0c757d5ed56', 'score': 1.0},
#  {'id': 'c1cd4c76-d3e7-4f51-ad90-3e4b70da51fd', 'score': 1.0},
#  {'id': 'a06888f4-61bb-4222-98c6-f9234ed455e2', 'score': 1.0},
#  {'id': '806b3cdd-76cc-4bdc-8e8f-4f291a67432b', 'score': 1.0},
#  {'id': '6456fd32-30c7-4341-af11-f90d097a0506', 'score': 1.0},
#  {'id': 'b95e8d0b-6157-4f93-b329-fc5b1d0a9211', 'score': 1.0},
#  {'id': '0e9e1c98-a21c-4d85-9444-17582fabe426', 'score': 1.0},
#  {'id': '4b371909-0482-4cc4-8b3b-c7fec1cd06a4', 'score': 1.0},
#  {'id': 'e66502f0-97f8-4a27-9515-0135abd5b90f', 'score': 1.0},
#  {'id': '53fce201-cae1-4822-a222-f4db544f1764', 'score': 1.0},
#  {'id': '43c876bb-25ab-4c38-b5b3-f7a2c20edbe7', 'score': 1.0},
#  {'id': 'fbb462f9-baa2-4e5b-9d5e-e4eb1c1e299d', 'score': 1.0},
#  {'id': '1328fb7c-ac85-48a7-a1e7-c1fec6de6b14', 'score': 1.0},
#  {'id': 'bcb869db-eee4-43ec-ab23-219c0f67b67b', 'score': 1.0},
#  {'id': 'aeb1a2d5-69dc-443f-847d-005df36087e7', 'score': 1.0},
#  {'id': '882bfe66-83d2-4c5f-9737-13aac10e6b1a', 'score': 1.0},
#  {'id': '75dc0b8b-5c75-4d78-b064-115000a7ea60', 'score': 1.0},
#  {'id': 'c2254b80-b0dc-40f3-bea3-ded54ae8200b', 'score': 1.0},
#  {'id': '841d0a8a-6125-4091-b99b-b3ef77d6514e', 'score': 1.0},
#  {'id': '5742fc3c-2e76-4942-97d2-fac9d0ee899a', 'score': 1.0},
#  {'id': '2bd9e0a7-7179-46b8-8d66-90142cb732dc', 'score': 1.0},
#  {'id': '3c192cc9-2a30-4f3b-a25b-6017e6650b1c', 'score': 1.0},
#  {'id': '1b7fce68-2014-4dea-9ff4-aa1c1d18fd1f', 'score': 1.0},
#  {'id': '72108911-6741-4bfe-9d69-08cbcca12d09', 'score': 1.0},
#  {'id': 'e0beb96f-fb5d-4228-8d56-463ebbb76c64', 'score': 1.0},
#  {'id': '9f3915ef-faca-4ffe-8905-adb576a222ff', 'score': 1.0},
#  {'id': '1746dcfa-9158-4d06-983b-59d62852c151', 'score': 1.0},
#  {'id': 'e9e06366-5834-4fb4-a630-445ec557aece', 'score': 1.0},
#  {'id': '79c6e0cf-751a-4ab7-965f-86cb14cc6369', 'score': 1.0},
#  {'id': 'c0ee64b2-7d51-493a-a02b-a847c22ff989', 'score': 1.0},
#  {'id': 'ad4c1553-bd6e-44e7-bf77-403867b4d05a', 'score': 1.0},
#  {'id': '655068d9-cb2c-4aa2-86f2-af89838d30ff', 'score': 1.0},
#  {'id': 'e0aea648-e0da-4d49-b3f9-2b1f7811e10e', 'score': 1.0},
#  {'id': '97002f8f-94a5-4e58-8563-c2ae4242124d', 'score': 1.0},
#  {'id': 'bc6760dc-4bce-497f-af64-a31ec35c55c5', 'score': 1.0},
#  {'id': 'cf1f124a-64a8-4dbc-8750-4f9dc9c32e0b', 'score': 1.0},
#  {'id': '1f2c5893-36c0-4640-9468-6bc691b2e142', 'score': 1.0},
#  {'id': '6c38666d-c73c-43e4-85ed-6619dc160589', 'score': 1.0},
#  {'id': '6182ce7e-2742-4284-baf3-71eb65649a1a', 'score': 1.0},
#  {'id': 'fe6f2528-bd43-4d32-a72f-0c37fa4a275d', 'score': 1.0},
#  {'id': 'aa9d3271-46ce-49c0-8f7d-4983c1a76ea2', 'score': 1.0},
#  {'id': 'cb2f61b7-62e8-45ac-ba83-998b51750bbb', 'score': 1.0},
#  {'id': 'f647a7e6-0909-4802-9a01-a33d9acfae79', 'score': 1.0},
#  {'id': '64dbb7fb-7c2c-40c5-90cf-1eb8aa6fb1d0', 'score': 1.0},
#  {'id': '45eec097-f75d-442b-897f-28eb1af1d94c', 'score': 1.0},
#  {'id': 'bfe5d7ca-8236-4c62-9f9e-ab4b1a96e0bb', 'score': 1.0},
#  {'id': '959358c3-d2ab-4496-9717-cf9013f90c50', 'score': 1.0},
#  {'id': '9b33af58-89b4-4866-9ce5-100555c9c102', 'score': 1.0},
#  {'id': '5e525f5e-be7e-4a49-94d0-8fda81dc465a', 'score': 1.0},
#  {'id': 'c2fbeb75-be15-487f-a4e3-893dd53f951f', 'score': 1.0},
#  {'id': 'c0683a6b-e19a-4313-87f9-19148f4c7e8f', 'score': 1.0},
#  {'id': 'c48fdcdd-c2bb-46e9-a67c-0fb354692ae4', 'score': 1.0},
#  {'id': '72337943-6594-44c1-b76f-ec9a462afb02', 'score': 1.0},
#  {'id': '84dba665-4c98-4118-984e-fefe36260ab7', 'score': 1.0},
#  {'id': '956ce5c4-0ace-43b5-b4b8-2dfc98b25416', 'score': 1.0},
#  {'id': 'b3660022-6430-488a-a246-a461f14fcce4', 'score': 1.0},
#  {'id': 'a7c2f70e-812c-4c71-9433-2c6f2a715a84', 'score': 1.0},
#  {'id': '8cf66323-a930-4af2-a38e-2f0e8342da0e', 'score': 1.0},
#  {'id': 'fe9f9955-d813-4c68-bcb6-40aef4acb9c3', 'score': 1.0},
#  {'id': '01dea5a3-256a-4923-a73f-f9b600df6d50', 'score': 1.0},
#  {'id': '0155f227-862d-401c-8afb-6f61153ba5d1', 'score': 1.0},
#  {'id': '2a6202b6-8d4e-432a-aee2-cd637e1650ad', 'score': 1.0},
#  {'id': 'f3918847-9c3d-4f98-a173-61ecbbb0ab74', 'score': 1.0},
#  {'id': '3393963a-3dbd-4e1d-9c16-88f5e6c2facb', 'score': 1.0},
#  {'id': 'fff987a5-85ee-4311-b6b9-a77fb3d967d8', 'score': 1.0},
#  {'id': 'd6c37d30-984c-4ee9-8c0a-b6b089901fef', 'score': 1.0},
#  {'id': 'd9fbd91d-9991-454b-bcc0-18cc5e7f3c70', 'score': 1.0},
#  {'id': '381970bc-3fa0-46c7-9529-5d8da2d25c4f', 'score': 1.0},
#  {'id': '66725cef-7a25-4687-870d-e2188770e345', 'score': 1.0},
#  {'id': '89ca6a51-6eba-4101-83df-e7cb7fd42bc0', 'score': 1.0},
#  {'id': '759a870f-90ce-4783-85be-883aa7c96d64', 'score': 1.0},
#  {'id': 'c6f9d7aa-275a-4651-8aa5-0b28fd0a515c', 'score': 1.0},
#  {'id': 'e99ac489-082b-4ba4-868d-42c6df14dbad', 'score': 1.0},
#  {'id': '31dc9961-25ee-4aa0-affe-6ef2876d3378', 'score': 1.0},
#  {'id': 'c225fc91-1a7a-4523-9995-f528cee233cb', 'score': 1.0},
#  {'id': '41232a7f-a74a-452d-a179-2a386895823f', 'score': 1.0},
#  {'id': '447536f7-11ce-4381-b072-aa1f9095630b', 'score': 1.0},
#  {'id': '2bd83ecd-1164-4f60-a700-7cd21cd660a0', 'score': 1.0},
#  {'id': 'dbe08c3c-cdab-4f64-8f11-2420f05344de', 'score': 1.0},
#  {'id': '054ee869-b0d3-4993-821b-ae1e77c3a5fc', 'score': 1.0},
#  {'id': 'a5c7d273-172c-46f5-82f3-027c6210aa11', 'score': 1.0},
#  {'id': '2681d38b-ac0d-45a8-910d-b590d62e5145', 'score': 1.0},
#  {'id': '8e5789d7-08e1-4775-9d04-cbf5c3cf5009', 'score': 1.0},
#  {'id': '8e8241ff-197d-4dec-9511-74434d9f7dea', 'score': 1.0},
#  {'id': '9484a159-4220-420b-989a-241af2c89fec', 'score': 1.0},
#  {'id': 'b6a3dd48-b6b7-4165-9127-730d03e507d5', 'score': 1.0},
#  {'id': '4997f1b3-4b88-40af-b0c1-adc4aaa5c0c7', 'score': 1.0},
#  {'id': 'df8515bd-abcc-4c53-8997-e2e453bd559a', 'score': 1.0},
#  {'id': '729f5346-763a-420d-8fe0-4d83ce9e8239', 'score': 1.0},
#  {'id': '1ec03d4e-d709-49d1-b733-0984e608e7af', 'score': 1.0},
#  {'id': 'e0c3eb06-d1c4-4fa5-8050-bc87c0670f9b', 'score': 1.0},
#  {'id': '7d53f008-dd11-43ef-9acb-b53d70d55c78', 'score': 1.0},
#  {'id': '587d8b37-8f07-47fe-95d4-4344232bd3d0', 'score': 1.0},
#  {'id': '6eb79bfe-799d-4d6e-866c-5943c8148c80', 'score': 1.0},
#  {'id': '3ee8466f-ef00-46ba-a7f9-59de9dcdfd68', 'score': 1.0},
#  {'id': 'b1b94d12-b247-413a-8367-3c49618a1cd4', 'score': 1.0},
#  {'id': 'bdd6fdde-e727-4b66-9819-b3c44585876c', 'score': 1.0},
#  {'id': '0dcb3728-4fd3-439d-83df-8e0444b9962d', 'score': 1.0},
#  {'id': '04db03d0-8615-4f11-b713-bc59f5cbdd5b', 'score': 1.0},
#  {'id': 'a6eded29-4124-445f-9a08-f53abd6282bc', 'score': 1.0},
#  {'id': 'ac487a72-971c-468f-8e48-a76446f62e03', 'score': 1.0},
#  {'id': 'f5b67671-3cb3-4eb7-b1ff-0d347f4a86c0', 'score': 1.0},
#  {'id': '0e8064b2-8282-4fe9-b1ac-bd0bb2d84c72', 'score': 1.0},
#  {'id': '076a22ea-200e-429a-8f09-8f339be0f283', 'score': 1.0},
#  {'id': 'dc91fc2f-e93f-4fcb-8508-b93657f5fc12', 'score': 1.0},
#  {'id': '22925a09-bcd2-42df-a6b3-ccc97d6c12f8', 'score': 1.0},
#  {'id': 'a050d83e-b13b-4a0a-b5e9-83827b0ad409', 'score': 1.0},
#  {'id': 'c0363921-7830-46ab-a8ed-cfc8e14adbe4', 'score': 1.0},
#  {'id': '16df0b7f-c818-4cdb-8609-d0c0bbac3641', 'score': 1.0},
#  {'id': '4fff9be0-cba0-4212-a8e5-24dc3c2d3621', 'score': 1.0},
#  {'id': '22d3637e-45b4-4918-ba94-71abc304eb03', 'score': 1.0},
#  {'id': '96a6684f-2e49-4f18-9d25-6ba2c12c4768', 'score': 1.0},
#  {'id': '0833592f-5315-4225-819f-84bb895fdb53', 'score': 1.0},
#  {'id': '0f3284e6-ac9b-4c9f-a76c-f99f23b68ac3', 'score': 1.0},
#  {'id': 'bdd4c402-09b4-47d9-a4fa-7ce294a08f2f', 'score': 1.0},
#  {'id': '0f7a6b92-8ddb-44ad-bf16-dd79001a73c6', 'score': 1.0},
#  {'id': '8b54382d-c61a-4095-a66b-06397013503b', 'score': 1.0},
#  {'id': '435590ae-e3e6-4e53-808e-44d5d035b6aa', 'score': 1.0},
#  {'id': 'fe2c96d5-fabd-4427-b335-7db4e0025bea', 'score': 1.0},
#  {'id': 'd927831e-6f5e-4a63-936c-2848a92677cd', 'score': 1.0},
#  {'id': 'a8bb39c1-826e-4731-a3db-c5a4bb95f64d', 'score': 1.0},
#  {'id': '475d120c-476a-4bfe-84f4-7b7d248cfe42', 'score': 1.0},
#  {'id': 'be65497e-8b77-46d2-a59f-7e5bc50ead5a', 'score': 1.0},
#  {'id': 'fc326b13-86bb-4473-941f-20c569566748', 'score': 1.0},
#  {'id': '91739912-f850-4857-9419-5c4485635924', 'score': 1.0},
#  {'id': '1a18d19f-8dbe-4760-9654-a85de2aecae6', 'score': 1.0},
#  {'id': '7271c335-aa63-4c81-9958-c7b89b6dfbcc', 'score': 1.0},
#  {'id': '387968bf-1dec-475d-a3e3-28d33045a2da', 'score': 1.0},
#  {'id': 'fc745dc3-39d4-464a-b465-39f8b1c90e09', 'score': 1.0},
#  {'id': '1e44f300-1e1e-49be-adb5-e3f06acfd157', 'score': 1.0},
#  {'id': '9a829a97-38c4-4879-8eb9-c400c6d15920', 'score': 1.0},
#  {'id': 'bf15652e-2995-4643-8329-2b70a6d4ba68', 'score': 1.0},
#  {'id': '77ac9666-03df-4982-a841-5a3fa22c423f', 'score': 1.0},
#  {'id': '211f78ca-f7fe-49b6-8a05-952082ba0bfb', 'score': 1.0},
#  {'id': 'ebba59a0-170b-478c-8ed1-4ad4b2fec77e', 'score': 1.0},
#  {'id': '9b5c01f1-4b94-4b1d-9325-414b9c743da5', 'score': 1.0},
#  {'id': '9fa510b6-6201-4a87-8ce8-234bd8524be4', 'score': 1.0},
#  {'id': '141a3107-1869-4429-be0f-b67d5866d7f0', 'score': 1.0},
#  {'id': 'df81a9dc-340a-46b6-93f1-012ed64892f3', 'score': 1.0},
#  {'id': '9b07d4e2-14b6-4008-851d-392c7c74b63a', 'score': 1.0},
#  {'id': 'b80433fe-ae3b-44fc-960e-8ba33f7c9abe', 'score': 1.0},
#  {'id': '9ec718d9-281e-4523-96c6-25669a139a52', 'score': 1.0},
#  {'id': '85b8e48b-28fd-48e8-930e-cb1374bfe52d', 'score': 1.0},
#  {'id': '1796df9c-4531-4c64-b608-c4bb135e2352', 'score': 1.0},
#  {'id': '39be69a3-3f2e-4601-9d92-e66a90805b0d', 'score': 1.0},
#  {'id': '7c76842f-dd47-4a28-af26-59683c09f921', 'score': 1.0},
#  {'id': 'c501b1d6-ca56-47ec-992b-57c69e7bcbd1', 'score': 1.0},
#  {'id': 'a6a5d51c-c9f2-495b-80d4-812be5a13051', 'score': 1.0},
#  {'id': 'f24ca141-b2b6-4ce6-8979-1829ddbf9981', 'score': 1.0},
#  {'id': '67c09ce1-8817-4865-b5a9-292b7c896d00', 'score': 1.0},
#  {'id': 'f48a049b-4f41-4b00-ab8c-232b3c8b8f9b', 'score': 1.0},
#  {'id': '9eb6dd10-ce75-441e-8059-416cbb11789d', 'score': 1.0},
#  {'id': '2d962087-a92b-47c5-9ae5-e74875359e7a', 'score': 1.0},
#  {'id': '2497e1d6-d23e-45c5-9b56-8699b3650670', 'score': 1.0},
#  {'id': '3628c734-3f3c-4a51-a28d-280b4664819d', 'score': 1.0},
#  {'id': '58718f51-a1e3-449e-ba3a-b21668b7df64', 'score': 1.0},
#  {'id': '3a4850a3-388f-46e8-a6a6-39d4cb9d5b7c', 'score': 1.0},
#  {'id': 'a0ac2390-2f2d-4d84-9ddd-c57c0b4fa7e8', 'score': 1.0},
#  {'id': '90331104-e531-46d6-8670-1ad93546061f', 'score': 1.0},
#  {'id': '4a2a4bda-4a63-49af-b269-1b62446b5ef7', 'score': 1.0},
#  {'id': 'e0107769-94eb-4fcc-9f4d-eb8749ea4cb8', 'score': 1.0},
#  {'id': 'ceedd050-b6e9-4a72-a574-49d405d59564', 'score': 1.0},
#  {'id': 'e3d5971e-16fb-4077-8fce-14bfbf36fae7', 'score': 1.0},
#  {'id': '40ab53b5-a03a-41a9-ac17-e4abb9cb58f6', 'score': 1.0},
#  {'id': '066ff047-6936-420c-9abb-655411341586', 'score': 1.0},
#  {'id': '86b238db-408c-48b7-861c-6e994ee10d75', 'score': 1.0},
#  {'id': 'f2ccbc1c-ec6b-4b21-8738-5568f63d0c10', 'score': 1.0},
#  {'id': '3d5e249a-1e56-41ab-ac63-e6d4473a52be', 'score': 1.0},
#  {'id': '50fcc37a-0427-461c-b29b-76517e289d59', 'score': 1.0},
#  {'id': 'b662ead0-d168-4881-a227-233a7e178193', 'score': 1.0},
#  {'id': 'a68ae7eb-6473-445d-89ec-6b667ae2e733', 'score': 1.0},
#  {'id': 'e4a0995b-a33c-4883-ae92-f03dcd74a510', 'score': 1.0},
#  {'id': 'bb8c1748-7231-490a-beaf-dc822e1e61f1', 'score': 1.0},
#  {'id': '30571eee-1180-447b-b64c-7f05eee8c125', 'score': 1.0},
#  {'id': '928e3b25-52b4-4e9e-9057-2df8cb7ee3f1', 'score': 1.0},
#  {'id': 'ed17a510-f22c-43d5-a916-4512a8be9ee3', 'score': 1.0},
#  {'id': '9f795b87-9034-4e83-9bed-4f78cde455ff', 'score': 1.0},
#  {'id': '11c1da4f-4cf0-4d25-8882-5c0039e89ff3', 'score': 1.0},
#  {'id': '5cb06a54-134c-4903-9fe1-661b636510a2', 'score': 1.0},
#  {'id': 'd8863b29-3ffd-4efb-bcd1-8402231e9684', 'score': 1.0},
#  {'id': '8ecb264c-81f5-4a80-b46a-836cd5180f8b', 'score': 1.0},
#  {'id': '16f486f8-0605-44dc-89fe-4527db9755f8', 'score': 1.0},
#  {'id': '0f342d87-6186-4743-8cc5-fc368ae94c09', 'score': 1.0},
#  {'id': 'a90cc2ab-febd-45be-92b1-535a2651b58b', 'score': 1.0},
#  {'id': '9ff320ae-e554-492d-ad45-27bd369f2935', 'score': 1.0},
#  {'id': 'dfc626c2-4265-488a-ab3c-9747ee10b310', 'score': 1.0},
#  {'id': '8a3103a9-6021-4d5e-8e79-06c6cfcaebea', 'score': 1.0},
#  {'id': '0b0e7a09-c41e-44f0-bde4-ebf81f93abad', 'score': 1.0},
#  {'id': '96b138d9-72ea-477a-a6f6-14a62ca279ea', 'score': 1.0},
#  {'id': '124c227f-06c1-4678-8e0a-800c41a29245', 'score': 1.0},
#  {'id': 'a63c335e-3b1f-4a60-aa18-9594c4cb9de4', 'score': 1.0},
#  {'id': 'c7c40af5-b620-4ad4-ab11-52d281dbb365', 'score': 1.0},
#  {'id': '37dfb507-4a48-4899-bdfb-7e0ba92b6b55', 'score': 1.0},
#  {'id': '98094ba6-cf3f-4cc7-93b3-0ff0cc895a30', 'score': 1.0},
#  {'id': 'b4ecc1c5-bce2-489f-9061-7df754be318c', 'score': 1.0},
#  {'id': '54adee37-1e14-4aeb-9daa-71a9b4295f84', 'score': 1.0},
#  {'id': 'f9905bdc-91d3-4ed2-a3fc-9c3c55fe439f', 'score': 1.0},
#  {'id': '9ac11a10-dddb-4c60-83d9-a44a67ae06fe', 'score': 1.0},
#  {'id': '86ef3fea-c224-42b8-a633-1d2aebd37e64', 'score': 1.0},
#  {'id': '33228a5c-67b2-498d-8a02-372894a2657f', 'score': 1.0},
#  {'id': '3b59dfce-90c9-4085-b19e-46695beed752', 'score': 1.0},
#  {'id': 'd2bcf3c2-1b06-43f5-8992-7299f652bcee', 'score': 1.0},
#  {'id': '3d3ecd9d-c317-4230-bc49-d3af573699f8', 'score': 1.0},
#  {'id': '6d7a2bd2-49ef-4939-b554-fd9c147de7c9', 'score': 1.0},
#  {'id': 'eba154ac-c857-4c34-b4b6-626ed8eeed67', 'score': 1.0},
#  {'id': 'c89c06ae-31ba-48f1-8540-32310d422052', 'score': 1.0},
#  {'id': '55385415-27c5-4036-8922-d313f173adc3', 'score': 1.0},
#  {'id': '282c0042-8482-4510-afc0-40f22a2755fa', 'score': 1.0},
#  {'id': 'a0bcf6bf-6632-4387-9d38-3b7e6dc0bd9b', 'score': 1.0},
#  {'id': 'aee130cd-400c-4194-b4a7-cee91f4d18a5', 'score': 1.0},
#  {'id': '3d6b9b5c-e101-4ad3-9c80-2d00f7c2e8ab', 'score': 1.0},
#  {'id': '4aeab3aa-8664-40ff-a2f8-eb8ffff43611', 'score': 1.0},
#  {'id': 'e30de6b5-fa5b-4016-96b2-0d741751bf03', 'score': 1.0},
#  {'id': '3a1b49ff-d644-40e9-a09f-8de4978566ba', 'score': 1.0},
#  {'id': 'eb4fe770-96ec-4e84-8843-b72234602b8a', 'score': 1.0},
#  {'id': '943ea7eb-42da-4fe3-9923-5b61cc55ac8c', 'score': 1.0},
#  {'id': 'dbbf3228-f88e-422e-b86a-66fb4c328fb0', 'score': 1.0},
#  {'id': '086e7c2b-d857-490e-864a-60474930ff0f', 'score': 1.0},
#  {'id': '900b8230-267a-4e12-b3c8-3cee29d56de2', 'score': 1.0},
#  {'id': '53d7e470-f3af-4662-a9db-0bbb8467665b', 'score': 1.0},
#  {'id': 'ee12bc3f-93a4-40d9-9fbb-4c917d8a916e', 'score': 1.0},
#  {'id': '24f808c1-ad22-4cca-baa9-ea4328955694', 'score': 1.0},
#  {'id': '5b887dc9-cf4f-48f9-8cd6-4acb720d7376', 'score': 1.0},
#  {'id': 'fc75f063-4433-4c27-b790-3f9af429071a', 'score': 1.0},
#  {'id': 'bff5a7a1-fd93-444c-9e47-692ded5440b0', 'score': 1.0},
#  {'id': 'afb8a38e-c891-4786-8aa4-95f3f37ba3c7', 'score': 1.0},
#  {'id': '0c5976bc-87b2-425d-875d-9cf26a05bc52', 'score': 1.0},
#  {'id': 'db0da60e-403f-4c58-b90e-0ef8bd44b013', 'score': 1.0},
#  {'id': '6318ac17-1029-4c91-a189-721264d62389', 'score': 1.0},
#  {'id': '64690bfe-cb86-40be-bfd2-a2f4a5a1393e', 'score': 1.0},
#  {'id': '6b7721e4-a74c-4518-b0fb-56680ea7bb20', 'score': 1.0},
#  {'id': 'd65d4bc7-acc2-4844-a2ed-17b30e069359', 'score': 1.0},
#  {'id': '63697138-fbfb-4ae4-aad9-128899974eb7', 'score': 1.0},
#  {'id': '5b8ad9e9-2f5b-47fe-9a96-3ba86aaa802b', 'score': 1.0},
#  {'id': 'e0a519a8-ba39-4d8d-9b1d-95b1c5ee6119', 'score': 1.0},
#  {'id': '8ae7091c-9932-4499-9a67-c44c921718a5', 'score': 1.0},
#  {'id': '291b8620-8ad6-41d6-a93d-a29bd614ebd0', 'score': 1.0},
#  {'id': 'f2346a28-b433-4fe5-9399-ab47853c0065', 'score': 1.0},
#  {'id': 'ad010577-aa53-451e-b07e-57075014e193', 'score': 1.0},
#  {'id': '3280707f-59c3-4bd1-a2bd-5294c26c9a11', 'score': 1.0},
#  {'id': '0ad5291c-69cc-41e7-9550-f2372e55218d', 'score': 1.0},
#  {'id': '07eb6921-8123-434e-92cc-23217e1011fe', 'score': 1.0},
#  {'id': '867de55b-5914-4d50-851a-236b634e915b', 'score': 1.0},
#  {'id': '35c18d7a-f057-4da5-a1e4-fac500c2c4cd', 'score': 1.0},
#  {'id': 'ba4fd8a8-b4e2-4386-b265-c222ca11704e', 'score': 1.0},
#  {'id': 'a07a895b-4186-4ced-b276-1d457fc129e6', 'score': 1.0},
#  {'id': 'f4f8a81e-7a82-4563-bc71-0e7aa565fb90', 'score': 1.0},
#  {'id': '5a8a5890-3b93-443a-95d2-d6e7472beaae', 'score': 1.0},
#  {'id': 'd245e962-b6a5-4f48-8f49-f871ce289fc5', 'score': 1.0},
#  {'id': '3956e332-bf44-4748-a9b9-fad3dd2a3e17', 'score': 1.0},
#  {'id': 'c6b64ba6-6402-4558-a83f-636557463ad3', 'score': 1.0},
#  {'id': '2ca051ea-b13c-4760-9144-c211ed037617', 'score': 1.0},
#  {'id': '3f951698-0681-468c-8529-7d8e5470b19a', 'score': 1.0},
#  {'id': 'a011ec6b-76a2-4793-9c7d-29b6783f5957', 'score': 1.0},
#  {'id': '9842759e-fe8e-492b-91a7-8a08b9c550eb', 'score': 1.0},
#  {'id': '111d1574-04c5-4d39-9eea-3d94a1aaf1d2', 'score': 1.0},
#  {'id': '38bed4c5-a1b1-4bd5-aa0c-47238f85ed90', 'score': 1.0},
#  {'id': 'b34a7f13-f18c-4323-9f0f-003fe659a209', 'score': 1.0},
#  {'id': 'f771b17f-a041-4992-9eb0-b46ceabe16cd', 'score': 1.0},
#  {'id': '399c9ab4-4853-45e8-835b-9b441eaa76f2', 'score': 1.0},
#  {'id': '51169844-b80a-458f-aa86-35deaacaa589', 'score': 1.0},
#  {'id': 'ce6fe910-30c8-4b5a-8705-b5ce257200df', 'score': 1.0},
#  {'id': 'd5988990-e0d8-4a83-aeb0-08077d71e7eb', 'score': 1.0},
#  {'id': 'c93bd024-bc45-451a-9fe7-d4acc44455a1', 'score': 1.0},
#  {'id': 'b0f178e5-b68c-4d18-8708-ab7376995794', 'score': 1.0},
#  {'id': '35f276ed-eeaa-4bff-98d4-790e2f5998df', 'score': 1.0},
#  {'id': 'b964dc65-de6c-41e0-882d-6ffb7ab83a17', 'score': 1.0},
#  {'id': '964c0e87-9789-424d-999e-223af4308ea9', 'score': 1.0},
#  {'id': 'd55036d0-2d46-4ced-aed5-fec519bac75a', 'score': 1.0},
#  {'id': 'e2db9fca-63c2-4d9d-bead-596b29d5124f', 'score': 1.0},
#  {'id': 'd28cb1ef-1e52-4d6a-a519-84495427ccd2', 'score': 1.0},
#  {'id': 'f87107a0-ee28-4a8e-82d5-ec4e8feefac8', 'score': 1.0},
#  {'id': '386c9407-1943-49db-858e-aa6b7e8dfe68', 'score': 1.0},
#  {'id': '127eac73-4348-4ea9-b39f-fae94b787d13', 'score': 1.0},
#  {'id': 'e0df3896-fba4-43d8-956f-e07cd68a44d6', 'score': 1.0},
#  {'id': '9be6a683-dc43-4a8f-83e6-688275ac4504', 'score': 1.0},
#  {'id': 'e56e7d3d-e88e-49bc-82e0-8819cb8dad2b', 'score': 1.0},
#  {'id': '1fe338dc-6b3e-4290-88e6-4a5aa58b43a3', 'score': 1.0},
#  {'id': 'eb42095c-5021-4796-8d6c-4a322bf6be21', 'score': 1.0},
#  {'id': 'e2039a46-bc83-4e5b-80c8-cb2a5d0bd07e', 'score': 1.0},
#  {'id': 'e070826b-7953-4599-9dfd-68497b414cd6', 'score': 1.0},
#  {'id': 'b069c0cb-ed25-4cd6-a9c6-5a8ea3cde690', 'score': 1.0},
#  {'id': 'c55e1971-36fe-4584-ae1f-ef196070c44e', 'score': 1.0},
#  {'id': '628134ea-6e35-49a9-b53c-9241b1b53496', 'score': 1.0},
#  {'id': '6de6aa73-acf9-47a1-aa37-3e00243d77f2', 'score': 1.0},
#  {'id': 'c19eea1d-702d-4b5c-9f92-06bc6bb4e0ee', 'score': 1.0},
#  {'id': '9d958d8b-9ceb-4720-8c12-daf3eff70c9d', 'score': 1.0},
#  {'id': 'a50a1915-b597-46fe-832f-e57453efc637', 'score': 1.0},
#  {'id': '1be323d6-262f-4284-9a4f-2f0e9be87b4d', 'score': 1.0},
#  {'id': '154850f2-bb50-44c0-b5f4-29bfd3059293', 'score': 1.0},
#  {'id': 'ea8f8d0d-e04a-4669-97a8-26b736c4d3b5', 'score': 1.0},
#  {'id': '9ed3dd8b-3c1c-499a-9bce-05fad257c236', 'score': 1.0},
#  {'id': '453b1864-1305-40ac-8842-00188d39a461', 'score': 1.0},
#  {'id': '7b5d8a79-c06a-498f-b060-56b737dad5f6', 'score': 1.0},
#  {'id': '6f236d88-84a9-49cf-8c1c-eda885f88401', 'score': 1.0},
#  {'id': '08b5eff8-b9a8-48d5-8917-27f7efa44af6', 'score': 1.0},
#  {'id': '9434962f-664f-470d-bfd6-08a384c71b99', 'score': 1.0},
#  {'id': 'e757e00c-a62d-4a73-b61a-69c228f77d38', 'score': 1.0},
#  {'id': 'a76935fd-2f7d-45f5-b282-43e35ec40af6', 'score': 1.0},
#  {'id': '626e2eba-076e-4657-aa9a-40a3ff5811fd', 'score': 1.0},
#  {'id': '860957e6-7a7c-4250-8bfd-44ac87ae4271', 'score': 1.0},
#  {'id': 'adef6bfe-34f4-4849-8bbe-d09205b9d526', 'score': 1.0},
#  {'id': '6e879e5c-1884-41c1-9436-40bd5fba6c27', 'score': 1.0},
#  {'id': 'dafd48a2-200e-4ca8-b4bd-ab450b42ca1e', 'score': 1.0},
#  {'id': 'a05572a7-e993-4bd7-9be7-e675295f25b2', 'score': 1.0},
#  {'id': '7de5e9e6-5a17-4e65-9bdf-dcab91afabb4', 'score': 1.0},
#  {'id': '86f331db-8166-4505-95ef-93a57c6fc180', 'score': 1.0},
#  {'id': 'accda504-c3bc-48e8-a9b1-86ab580125cd', 'score': 1.0},
#  {'id': 'ea264ea3-7571-43a6-b716-5adf1653ec42', 'score': 1.0},
#  {'id': 'dc9671b0-f427-48b5-a15a-78c2eaba0d6b', 'score': 1.0},
#  {'id': 'bf57a97f-6735-498b-b63e-2e8308312725', 'score': 1.0},
#  {'id': 'd20c3e65-aadd-4f4b-8043-a66a0512473a', 'score': 1.0},
#  {'id': '9a62e550-00ec-4af8-a323-189d84eaf87b', 'score': 1.0},
#  {'id': '87d85c75-09ba-40aa-9703-520f7c986a76', 'score': 1.0},
#  {'id': 'bcb45112-f3a3-41b4-9b2c-fdd8133ce8d8', 'score': 1.0},
#  {'id': '0b628d37-2511-4b7c-b4d2-580b3ebb82aa', 'score': 1.0},
#  {'id': '824ac866-f455-436b-8030-58cf7a6dc925', 'score': 1.0},
#  {'id': '6e9f6cf9-e39a-48df-a3e2-0bcd72223624', 'score': 1.0},
#  {'id': 'c33db4cb-07f8-4a08-9448-490f88dd640c', 'score': 1.0},
#  {'id': 'd8fe5659-99f9-4201-92d1-fbfea2200507', 'score': 1.0},
#  {'id': '72674918-2260-4309-adb0-09f5a384ccd2', 'score': 1.0},
#  {'id': 'bc373cdb-67f2-44de-828a-f81abd80622c', 'score': 1.0},
#  {'id': '268266b1-48de-40d5-865c-42226a2c60de', 'score': 1.0},
#  {'id': 'eab4a378-bcb7-4d78-b458-2c1c17b86919', 'score': 1.0},
#  {'id': '61b55342-da7d-47e6-8ea9-5e48d51ae87e', 'score': 1.0},
#  {'id': 'e46dabd4-fa85-4879-b68f-f42d8a067306', 'score': 1.0},
#  {'id': 'ccee38c9-95f9-4516-8036-6f247f8933ad', 'score': 1.0},
#  {'id': '5976d877-40d3-415d-b2d2-556516cad16a', 'score': 1.0},
#  {'id': 'be29f2ce-82a5-402d-812d-c3b88831bb57', 'score': 1.0},
#  {'id': 'f33a1908-669f-4880-955e-c14e48fc5035', 'score': 1.0},
#  {'id': 'e222c9ec-7faf-40ce-8ed3-8b83c3989136', 'score': 1.0},
#  {'id': '8d6208bc-9ca3-4f3b-8ae9-03112d633bea', 'score': 1.0},
#  {'id': '05fa517e-ae1e-46cf-849c-3f96d7a9a2ce', 'score': 1.0},
#  {'id': '1d9b83d8-7f20-44ad-a8d8-07bc0c710b30', 'score': 1.0},
#  {'id': '41a3c4ff-8d2d-472e-b15b-9992bac0ee1d', 'score': 1.0},
#  {'id': '687794da-0ebc-4906-bc42-a55786bc8f2f', 'score': 1.0},
#  {'id': '6376b80a-a3c4-4690-90f6-68948113b0b0', 'score': 1.0},
#  {'id': 'd816b300-8a6c-4ca6-b827-75998b9055b1', 'score': 1.0},
#  {'id': '388c5676-4384-4bae-9aa8-4f399656a2b9', 'score': 1.0},
#  {'id': 'bfb7fb00-155a-4cf3-8e77-a278bc01247f', 'score': 1.0},
#  {'id': 'fb0a9e1c-165c-41ce-b918-fc3355fb8fa0', 'score': 1.0},
#  {'id': '272c5d25-29e0-4fc7-965d-e4d506eef1b9', 'score': 1.0},
#  {'id': '6f3c354a-d41c-42a3-8395-8bc8701d51e1', 'score': 1.0},
#  {'id': 'bd21607e-8f0f-40e5-937f-53ca41c0ed58', 'score': 1.0},
#  {'id': 'f2db6c44-e9e1-4c34-b987-e579a46cb694', 'score': 1.0},
#  {'id': 'a8ee269c-e08b-479d-8cd5-dc76f2e5091e', 'score': 1.0},
#  {'id': 'e40e388c-83b7-4862-8a6c-39178037fe8b', 'score': 1.0},
#  {'id': '1aa5ae12-8375-4524-aef1-5afae14b31fd', 'score': 1.0},
#  {'id': '0b59e254-2374-4674-b93d-fbf2bebaa9fa', 'score': 1.0},
#  {'id': 'a059cf4e-f4a3-4d7e-8ce6-e6a612236d68', 'score': 1.0},
#  {'id': 'e6e19ff0-96ea-466e-86eb-26dc0f59cc27', 'score': 1.0},
#  {'id': '8fdc1800-76fc-4c14-a760-25016fcbdf7d', 'score': 1.0},
#  {'id': 'd726b259-70b9-4da0-bd90-d0993f25d543', 'score': 1.0},
#  {'id': '7b8e1c05-5aa0-4f95-8fdc-4cd1b36f863d', 'score': 1.0},
#  {'id': 'bbe26468-7fda-4a81-83e7-8b706827cd9d', 'score': 1.0},
#  {'id': '9ec74c70-859d-472c-b79f-5161b610e8cc', 'score': 1.0},
#  {'id': 'b63b799d-e8fd-4c17-ae15-e5406db823c3', 'score': 1.0},
#  {'id': '16ebec1a-18bd-4639-9f17-fe353a8143aa', 'score': 1.0},
#  {'id': 'b3afc57a-0d8e-4a1b-b188-687e1f93e066', 'score': 1.0},
#  {'id': '38e4f0e7-fd64-4aac-b3ee-2487891e62c9', 'score': 1.0},
#  {'id': '64c075f4-19c3-48dd-b2ec-89c5ff268c12', 'score': 1.0},
#  {'id': '8d5b5ef0-61d1-4715-8a87-f351a1e6ae28', 'score': 1.0},
#  {'id': '8d6e9faa-2de7-4f8e-845b-42db37c766ef', 'score': 1.0},
#  {'id': '0d44742c-0003-4ab7-916f-96524423d37b', 'score': 1.0},
#  {'id': '7a2ce85d-6bf8-4aa4-bd0d-1315105d37ea', 'score': 1.0},
#  {'id': 'c52d3d97-5597-41d8-a85b-70265cea431a', 'score': 1.0},
#  {'id': '6f12bae1-08ea-40f0-9a34-2b92a85a9b63', 'score': 1.0},
#  {'id': '03efe671-4706-4256-af3b-a7ab91623131', 'score': 1.0},
#  {'id': '68e4fa69-3a4d-4c07-a26c-2be5de7100c2', 'score': 1.0},
#  {'id': 'efe5659d-a900-402f-ac43-7f9ea7e01819', 'score': 1.0},
#  {'id': 'c2648dcb-cc67-4025-bcda-79fab281dd13', 'score': 1.0},
#  {'id': '59d068e8-c0ad-4747-8c30-e78a7f4823bd', 'score': 1.0},
#  {'id': 'ac2e5de2-5bfd-44e0-85f0-a0a6eb3059f7', 'score': 1.0},
#  {'id': 'abf29e9f-f971-4704-a9b4-9475faa7cac3', 'score': 1.0},
#  {'id': '3163ba78-baa0-4dd8-ace8-09578c9c5f94', 'score': 1.0},
#  {'id': '7794467b-41f7-406b-b52b-fd3d4e70d0e8', 'score': 1.0},
#  {'id': 'ed68c956-754e-4a26-b1c7-f2083bf8319d', 'score': 1.0},
#  {'id': 'a3aad424-223c-481e-84e7-dc844a9601c6', 'score': 1.0},
#  {'id': 'c49f864b-81db-47cd-ae19-63c89477655e', 'score': 1.0},
#  {'id': '748c4c07-c057-4c22-be06-e69cb2a62a5f', 'score': 1.0},
#  {'id': '7c12229c-d86e-4779-8c24-033dbdaf0f48', 'score': 1.0},
#  {'id': '1a0b4df3-482b-4537-8aaf-58f64d682ed3', 'score': 1.0},
#  {'id': 'c336288f-3fbf-4f1d-b201-bae14f43ce03', 'score': 1.0},
#  {'id': '7b794ab7-dc1c-4774-8306-64ee457823f1', 'score': 1.0},
#  {'id': '5a82505f-9912-4ba6-85e6-c51073de10c2', 'score': 1.0},
#  {'id': 'f8b0737b-2cf3-4438-9d48-4e6852292c21', 'score': 1.0},
#  {'id': 'dc0e3a3f-4794-468a-9bda-fd4b14c7db44', 'score': 1.0},
#  {'id': 'c227889e-f896-480f-b9c8-4e6f7f0bac8b', 'score': 1.0},
#  ...]

# %%
import json
import os

filename = f"RAID_predictions_{'with' if INCLUDE_ADVERSARIAL else 'no'}_adversarial{'_rounded' if ROUND_PREDICTIONS else ''}.json"

directory = os.path.splitext(MODEL_VERSION)[0]
if not os.path.exists(directory):
    os.makedirs(directory)

output = os.path.join(directory, filename)
print(output)
with open(output, 'w') as f:
    json.dump(predictions, f)
# Out:
# luminar_classifier_RAID/RAID_predictions_with_adversarial_rounded.json
